# %%
import requests

url = "https://opensource-demo.orangehrmlive.com/web/index.php/api/v2/time/customers"

payload = { "name": "ABC Corporation" }
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer "
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"data":{"id":10,"name":"ABC Corporation","description":"","deleted":false},"meta":[],"rels":[]}

# %%
response.status_code
# Out:
# 200

# %%
url = "https://opensource-demo.orangehrmlive.com/web/index.php/api/v2/time/project-admins"

headers = {
    "accept": "application/json",
    "authorization": "Bearer "
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"data":[{"empNumber":104,"lastName":"010Z","firstName":"A8DCo","middleName":"4Ys","employeeId":"0312","terminationId":null},{"empNumber":128,"lastName":"444444","firstName":"123445","middleName":"34","employeeId":"dfgsjsjdh","terminationId":null},{"empNumber":86,"lastName":"5TlV","firstName":"99N75","middleName":"425","employeeId":"0295","terminationId":null},{"empNumber":136,"lastName":"90jsnd","firstName":"yedghjb1","middleName":"ru84","employeeId":"09876","terminationId":null},{"empNumber":175,"lastName":"A","firstName":"Yamuna","middleName":"","employeeId":"54348Y","terminationId":null},{"empNumber":69,"lastName":"Akunuri","firstName":"Ranga","middleName":"","employeeId":"0277","terminationId":null},{"empNumber":185,"lastName":"Alister","firstName":"Alexis","middleName":"","employeeId":"0388","terminationId":null},{"empNumber":184,"lastName":"Alister","firstName":"Alexis","middleName":"Mac","employeeId":"0387","terminationId":null},{"empNumber":180,"lastName":"Alister","firstName":"Alexis","middleName":"","employeeId":"0383","terminationId":null},{"empNumber":179,"lastName":"Alister","firstName":"Alexis","middleName":"Mac","employeeId":"0382","terminationId":null},{"empNumber":95,"lastName":"Amiano","firstName":"Timothy","middleName":"Lewis","employeeId":"0039","terminationId":null},{"empNumber":3,"lastName":"Anderson","firstName":"Peter","middleName":"Mac","employeeId":"0007","terminationId":null},{"empNumber":46,"lastName":"B","firstName":"Ravi","middleName":"M","employeeId":"3322","terminationId":null},{"empNumber":166,"lastName":"Benny","firstName":"Thomas","middleName":"Kutty","employeeId":"03694567","terminationId":null},{"empNumber":116,"lastName":"Brown","firstName":"Amelia","middleName":"","employeeId":"01715","terminationId":null},{"empNumber":160,"lastName":"Butler","firstName":"James","middleName":"","employeeId":"0365","terminationId":null},{"empNumber":113,"lastName":"Carter","firstName":"Charles","middleName":"","employeeId":"0320","terminationId":null},{"empNumber":167,"lastName":"Carter222","firstName":"Charles111","middleName":"","employeeId":"0370","terminationId":null},{"empNumber":101,"lastName":"Das","firstName":"Rahul","middleName":"","employeeId":"123","terminationId":null},{"empNumber":99,"lastName":"Das","firstName":"Rahul","middleName":"","employeeId":"kkt","terminationId":null},{"empNumber":98,"lastName":"Das","firstName":"Rahul","middleName":"","employeeId":null,"terminationId":null},{"empNumber":97,"lastName":"Das","firstName":"Rahul","middleName":"","employeeId":null,"terminationId":null},{"empNumber":96,"lastName":"Das","firstName":"Rahul","middleName":"","employeeId":"0304","terminationId":null},{"empNumber":94,"lastName":"dulvin","firstName":"savina","middleName":"dulvin","employeeId":"0303029900","terminationId":null},{"empNumber":84,"lastName":"dulvin","firstName":"savina","middleName":"dulvin","employeeId":"0293029900","terminationId":null},{"empNumber":82,"lastName":"dulvin","firstName":"savina","middleName":"dulvin","employeeId":"0291029900","terminationId":null},{"empNumber":182,"lastName":"E48","firstName":"Test","middleName":"","employeeId":"0385T85206","terminationId":null},{"empNumber":177,"lastName":"E56","firstName":"Test","middleName":"","employeeId":"0379T56213","terminationId":null},{"empNumber":169,"lastName":"E96","firstName":"Test","middleName":"","employeeId":"0372T17929","terminationId":null},{"empNumber":181,"lastName":"Employee2451","firstName":"Test3152","middleName":"","employeeId":"0384","terminationId":null},{"empNumber":156,"lastName":"Evans","firstName":"Joseph","middleName":"","employeeId":"0361","terminationId":null},{"empNumber":172,"lastName":"G","firstName":"Raju","middleName":"","employeeId":"54347R","terminationId":null},{"empNumber":58,"lastName":"g","firstName":"savi","middleName":"N","employeeId":"0266","terminationId":null},{"empNumber":190,"lastName":"gfndhn","firstName":"Asen","middleName":"","employeeId":"9000","terminationId":null},{"empNumber":1 ...
