# %%
from openpyxl import Workbook
from openpyxl.styles import Alignment
import os

# Create workbook object
input_file = 'DangBaQui_Group1_OrangeHRM_Projects.xlsx'
wb = Workbook()
ws_testdesign = wb.active
ws_testdesign.title = "TestDesign"


print("=" * 80)
print("THÊM 149 TEST CRITERIA VÀO SHEET TESTDESIGN")
print("=" * 80)

# ============================================================================
# XÓA PROJECTS CRITERIA CŨ (nếu có)
# ============================================================================
print("\nBước 1: Xóa Projects criteria cũ...")

rows_to_delete = []
for row_idx in range(1, ws_testdesign.max_row + 1):
    cell_value = ws_testdesign.cell(row=row_idx, column=1).value
    note_value = ws_testdesign.cell(row=row_idx, column=6).value

    if (cell_value and 'Project' in str(cell_value)) or (note_value and 'Projects-' in str(note_value)):
        rows_to_delete.append(row_idx)

# Delete from bottom to top
for row_idx in sorted(set(rows_to_delete), reverse=True):
    ws_testdesign.delete_rows(row_idx, 1)

print(f"✅ Đã xóa {len(set(rows_to_delete))} dòng cũ")

# ============================================================================
# THÊM 149 TEST CRITERIA CHO PROJECTS-INFO
# ============================================================================
print("\nBước 2: Thêm 149 test criteria mới...")

# Complete Test Criteria for Projects-info (149 criteria)
projects_criteria = [
    # Module header
    ["1. Projects", "1.1 Add Project - Positive", "Basic Project - TC01", "Kiểm tra navigate to Time → Projects menu", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra click Add Project button", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra Add Project form hiển thị", "GUI", "Projects-info-1"],
    [None, None, None, "Kiểm tra Project Name input field visible", "GUI", "Projects-info-1"],
    [None, None, None, "Kiểm tra Customer Name dropdown visible", "GUI", "Projects-info-1"],
    [None, None, None, "Kiểm tra nhập Project Name", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra select Customer từ dropdown", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra Customer dropdown load danh sách customers", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra click Save button", "Function", "Projects-info-1"],
    [None, None, None, "Kiểm tra success message hiển thị", "Validation", "Projects-info-1"],
    [None, None, None, "Kiểm tra project xuất hiện trong table", "Validation", "Projects-info-1"],
    [None, None, None, "Kiểm tra search project functionality", "Function", "Projects-info-1"],

    # Projects-info-6
    [None, None, "With Admin - TC06", "Kiểm tra Project Admin input field visible", "GUI", "Projects-info-6"],
    [None, None, None, "Kiểm tra nhập Project Admin name (autocomplete)", "Function", "Projects-info-6"],
    [None, None, None, "Kiểm tra Project Admin dropdown load suggestions", "Function", "Projects-info-6"],
    [None, None, None, "Kiểm tra select Project Admin từ dropdown", "Function", "Projects-info-6"],
    [None, None, None, "Kiểm tra keyboard navigation (ArrowDown, Enter) cho Project Admin", "Function", "Projects-info-6"],
    [None, None, None, "Kiểm tra save project với Project Admin", "Function", "Projects-info-6"],
    [None, None, None, "Kiểm tra success message với Project Admin", "Validation", "Projects-info-6"],

    # Projects-info-7
    [None, None, "With Description - TC07", "Kiểm tra Description textarea visible", "GUI", "Projects-info-7"],
    [None, None, None, "Kiểm tra nhập Description text", "Function", "Projects-info-7"],
    [None, None, None, "Kiểm tra Description textarea accept multi-line text", "Function", "Projects-info-7"],
    [None, None, None, "Kiểm tra save project với Description", "Function", "Projects-info-7"],
    [None, None, None, "Kiểm tra Description được lưu chính xác", "Validation", "Projects-info-7"],

    # Projects-info-2
    [None, "1.2 Add Project - Negative", "Empty Customer - TC02", "Kiểm tra click Add Project", "Function", "Projects-info-2"],
    [None, None, None, "Kiểm tra nhập Project Name nhưng KHÔNG chọn Customer", "Function", "Projects-info-2"],
    [None, None, None, "Kiểm tra click Save với Customer trống", "Function", "Projects-info-2"],
    [None, None, None, "Kiểm tra error message 'Required' hiển thị cho Customer field", "Validation", "Projects-info-2"],
    [None, None, None, "Kiểm tra Customer field highlight màu đỏ", "GUI", "Projects-info-2"],
    [None, None, None, "Kiểm tra form KHÔNG submit khi Customer trống", "Validation", "Projects-info-2"],

    # Projects-info-3
    [None, None, "Empty Name - TC03", "Kiểm tra chọn Customer nhưng KHÔNG nhập Project Name", "Function", "Projects-info-3"],
    [None, None, None, "Kiểm tra click Save với Project Name trống", "Function", "Projects-info-3"],
    [None, None, None, "Kiểm tra error message 'Required' hiển thị cho Project Name field", "Validation", "Projects-info-3"],
    [None, None, None, "Kiểm tra Project Name field highlight màu đỏ", "GUI", "Projects-info-3"],
    [None, None, None, "Kiểm tra form KHÔNG submit khi Project Name trống", "Validation", "Projects-info-3"],

    # Projects-info-4
    [None, None, "Exceeding 50 chars - TC04", "Kiểm tra nhập Project Name = 51 ký tự", "Function", "Projects-info-4"],
    [None, None, None, "Kiểm tra input value sau khi nhập (truncate hoặc accept)", "Validation", "Projects-info-4"],
    [None, None, None, "Kiểm tra max length constraint = 50 ký tự", "Validation", "Projects-info-4"],
    [None, None, None, "Kiểm tra error message nếu vượt quá 50 ký tự", "Validation", "Projects-info-4"],
    [None, None, None, "Kiểm tra Project Name field behavior với long input", "Function", "Projects-info-4"],

    # Projects-info-5
    [None, None, "Duplicate Name - TC05", "Kiểm tra add project lần 1 (tạo project gốc)", "Function", "Projects-info-5"],
    [None, None, None, "Kiểm tra success message cho project lần 1", "Validation", "Projects-info-5"],
    [None, None, None, "Kiểm tra navigate lại Add Project form", "Function", "Projects-info-5"],
    [None, None, None, "Kiểm tra nhập Project Name TRÙNG với project đã tồn tại", "Function", "Projects-info-5"],
    [None, None, None, "Kiểm tra click Save với duplicate name", "Function", "Projects-info-5"],
    [None, None, None, "Kiểm tra error message 'Already exists' hiển thị", "Validation", "Projects-info-5"],
    [None, None, None, "Kiểm tra duplicate validation working", "Validation", "Projects-info-5"],

    # ACTIVITIES
    [None, "1.3 Add Activity - Positive", "Valid Activity - TC08", "Kiểm tra navigate to Projects list page", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra search và click Edit project", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra project edit page hiển thị", "GUI", "Projects-info-8"],
    [None, None, None, "Kiểm tra scroll to Activities section", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra Activities section visible", "GUI", "Projects-info-8"],
    [None, None, None, "Kiểm tra Add Activity button visible", "GUI", "Projects-info-8"],
    [None, None, None, "Kiểm tra click Add Activity button", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra Activity Name input field xuất hiện", "GUI", "Projects-info-8"],
    [None, None, None, "Kiểm tra nhập Activity Name", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra click Save activity", "Function", "Projects-info-8"],
    [None, None, None, "Kiểm tra success message hiển thị", "Validation", "Projects-info-8"],
    [None, None, None, "Kiểm tra activity xuất hiện trong activity table", "Validation", "Projects-info-8"],

    # Projects-info-12
    [None, None, "Edit Activity - TC12", "Kiểm tra create activity trước khi edit", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra scroll to activity list", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra find activity row trong table", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra click Edit button cho activity", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra Activity Name input editable", "GUI", "Projects-info-12"],
    [None, None, None, "Kiểm tra clear old name và nhập new name", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra click Save edited activity", "Function", "Projects-info-12"],
    [None, None, None, "Kiểm tra success message sau edit", "Validation", "Projects-info-12"],
    [None, None, None, "Kiểm tra activity name updated trong table", "Validation", "Projects-info-12"],

    # Projects-info-9
    [None, "1.4 Add Activity - Negative", "Empty Name - TC09", "Kiểm tra click Add Activity", "Function", "Projects-info-9"],
    [None, None, None, "Kiểm tra Activity Name input visible", "GUI", "Projects-info-9"],
    [None, None, None, "Kiểm tra KHÔNG nhập Activity Name (để trống)", "Function", "Projects-info-9"],
    [None, None, None, "Kiểm tra click Save với empty name", "Function", "Projects-info-9"],
    [None, None, None, "Kiểm tra error message 'Required' hiển thị", "Validation", "Projects-info-9"],
    [None, None, None, "Kiểm tra Activity Name field highlight màu đỏ", "GUI", "Projects-info-9"],
    [None, None, None, "Kiểm tra form KHÔNG submit khi name trống", "Validation", "Projects-info-9"],

    # Projects-info-10
    [None, None, "Exceeding 100 chars - TC10", "Kiểm tra click Add Activity", "Function", "Projects-info-10"],
    [None, None, None, "Kiểm tra nhập Activity Name = 101 ký tự", "Function", "Projects-info-10"],
    [None, None, None, "Kiểm tra tab out/blur event", "Function", "Projects-info-10"],
    [None, None, None, "Kiểm tra error message 'Should not exceed 100 characters' hiển thị", "Validation", "Projects-info-10"],
    [None, None, None, "Kiểm tra max length constraint = 100 ký tự", "Validation", "Projects-info-10"],
    [None, None, None, "Kiểm tra Activity Name field với long input", "Function", "Projects-info-10"],

    # Projects-info-11
    [None, None, "Duplicate Activity - TC11", "Kiểm tra add activity lần 1 (tạo activity gốc)", "Function", "Projects-info-11"],
    [None, None, None, "Kiểm tra success message cho activity lần 1", "Validation", "Projects-info-11"],
    [None, None, None, "Kiểm tra click Add Activity lần 2", "Function", "Projects-info-11"],
    [None, None, None, "Kiểm tra nhập Activity Name TRÙNG với activity đã tồn tại", "Function", "Projects-info-11"],
    [None, None, None, "Kiểm tra click Save với duplicate name", "Function", "Projects-info-11"],
    [None, None, None, "Kiểm tra error message 'Already exists' hiển thị", "Validation", "Projects-info-11"],
    [None, None, None, "Kiểm tra duplicate validation trong cùng project", "Validation", "Projects-info-11"],

    # CUSTOMERS
    [None, "1.5 Add Customer - Positive", "Name + Description - TC13", "Kiểm tra navigate to Admin → Customers menu", "Function", "Projects-info-13"],
    [None, None, None, "Kiểm tra click Add Customer button", "Function", "Projects-info-13"],
    [None, None, None, "Kiểm tra Add Customer form hiển thị", "GUI", "Projects-info-13"],
    [None, None, None, "Kiểm tra Customer Name input field visible", "GUI", "Projects-info-13"],
    [None, None, None, "Kiểm tra Description textarea visible", "GUI", "Projects-info-13"],
    [None, None, None, "Kiểm tra nhập Customer Name", "Function", "Projects-info-13"],
    [None, None, None, "Kiểm tra nhập Description", "Function", "Projects-info-13"],
    [None, None, None, "Kiểm tra click Save customer", "Function", "Projects-info-13"],
    [None, None, None, "Kiểm tra success message hiển thị", "Validation", "Projects-info-13"],
    [None, None, None, "Kiểm tra customer xuất hiện trong table", "Validation", "Projects-info-13"],

    # Projects-info-14
    [None, None, "Name Only - TC14", "Kiểm tra click Add Customer", "Function", "Projects-info-14"],
    [None, None, None, "Kiểm tra nhập Customer Name", "Function", "Projects-info-14"],
    [None, None, None, "Kiểm tra KHÔNG nhập Description (optional field)", "Function", "Projects-info-14"],
    [None, None, None, "Kiểm tra click Save customer without description", "Function", "Projects-info-14"],
    [None, None, None, "Kiểm tra success message", "Validation", "Projects-info-14"],
    [None, None, None, "Kiểm tra customer saved successfully without description", "Validation", "Projects-info-14"],
    [None, None, None, "Kiểm tra Description là optional field", "Validation", "Projects-info-14"],

    # Projects-info-15
    [None, "1.6 Add Customer - Negative", "Empty Name - TC15", "Kiểm tra click Add Customer", "Function", "Projects-info-15"],
    [None, None, None, "Kiểm tra KHÔNG nhập Customer Name (để trống)", "Function", "Projects-info-15"],
    [None, None, None, "Kiểm tra click Save với empty name", "Function", "Projects-info-15"],
    [None, None, None, "Kiểm tra error message 'Required' hiển thị", "Validation", "Projects-info-15"],
    [None, None, None, "Kiểm tra Customer Name field highlight màu đỏ", "GUI", "Projects-info-15"],
    [None, None, None, "Kiểm tra form KHÔNG submit khi name trống", "Validation", "Projects-info-15"],

    # Projects-info-16
    [None, None, "Exceeding 50 chars - TC16", "Kiểm tra nhập Customer Name = 51 ký tự", "Function", "Projects-info-16"],
    [None, None, None, "Kiểm tra tab out/blur event", "Function", "Projects-info-16"],
    [None, None, None, "Kiểm tra error message 'Should not exceed 50 characters' hoặc truncate", "Validation", "Projects-info-16"],
    [None, None, None, "Kiểm tra max length constraint = 50 ký tự", "Validation", "Projects-info-16"],
    [None, None, None, "Kiểm tra Customer Name field với long input", "Function", "Projects-info-16"],

    # Projects-info-17
    [None, None, "Duplicate Name - TC17", "Kiểm tra add customer lần 1 (tạo customer gốc)", "Function", "Projects-info-17"],
    [None, None, None, "Kiểm tra success message cho customer lần 1", "Validation", "Projects-info-17"],
    [None, None, None, "Kiểm tra navigate lại Add Customer form", "Function", "Projects-info-17"],
    [None, None, None, "Kiểm tra nhập Customer Name TRÙNG với customer đã tồn tại", "Function", "Projects-info-17"],
    [None, None, None, "Kiểm tra click Save với duplicate name", "Function", "Projects-info-17"],
    [None, None, None, "Kiểm tra error message 'Already exists' hiển thị", "Validation", "Projects-info-17"],
    [None, None, None, "Kiểm tra duplicate validation working", "Validation", "Projects-info-17"],

    # Projects-info-18
    [None, "1.7 Add Customer - Security", "Script Injection - TC18", "Kiểm tra nhập Customer Name với special characters (<script>alert('XSS')</script>)", "Function", "Projects-info-18"],
    [None, None, None, "Kiểm tra click Save với script injection", "Function", "Projects-info-18"],
    [None, None, None, "Kiểm tra system sanitize input (không execute script)", "Security", "Projects-info-18"],
    [None, None, None, "Kiểm tra customer saved với escaped characters", "Validation", "Projects-info-18"],
    [None, None, None, "Kiểm tra XSS prevention", "Security", "Projects-info-18"],

    # Projects-info-19
    [None, "1.8 Add Customer - Boundary", "Exactly 50 chars - TC19", "Kiểm tra nhập Customer Name = EXACTLY 50 ký tự", "Function", "Projects-info-19"],
    [None, None, None, "Kiểm tra accept boundary value (50 chars)", "Validation", "Projects-info-19"],
    [None, None, None, "Kiểm tra click Save với 50 ký tự", "Function", "Projects-info-19"],
    [None, None, None, "Kiểm tra success message", "Validation", "Projects-info-19"],
    [None, None, None, "Kiểm tra customer saved successfully với 50 chars", "Validation", "Projects-info-19"],
    [None, None, None, "Kiểm tra boundary test: max value accepted", "Validation", "Projects-info-19"],

    # Projects-info-20
    [None, "1.9 Add Customer - Edge Cases", "Special Characters - TC20", "Kiểm tra nhập Customer Name với @#$%^&*()", "Function", "Projects-info-20"],
    [None, None, None, "Kiểm tra system accept hoặc reject special characters", "Validation", "Projects-info-20"],
    [None, None, None, "Kiểm tra click Save với special chars", "Function", "Projects-info-20"],
    [None, None, None, "Kiểm tra behavior với various special characters", "Validation", "Projects-info-20"],

    # Projects-info-21
    [None, None, "Leading/Trailing Spaces - TC21", "Kiểm tra nhập Customer Name với spaces ở đầu ('  Customer')", "Function", "Projects-info-21"],
    [None, None, None, "Kiểm tra nhập Customer Name với spaces ở cuối ('Customer  ')", "Function", "Projects-info-21"],
    [None, None, None, "Kiểm tra system trim leading/trailing spaces", "Validation", "Projects-info-21"],
    [None, None, None, "Kiểm tra click Save", "Function", "Projects-info-21"],
    [None, None, None, "Kiểm tra customer name saved without extra spaces", "Validation", "Projects-info-21"],
    [None, None, None, "Kiểm tra data sanitization for spaces", "Validation", "Projects-info-21"],

    # Projects-info-22
    [None, None, "Numeric Name - TC22", "Kiểm tra nhập Customer Name = '12345' (chỉ số)", "Function", "Projects-info-22"],
    [None, None, None, "Kiểm tra system accept numeric-only name", "Validation", "Projects-info-22"],
    [None, None, None, "Kiểm tra click Save với numeric name", "Function", "Projects-info-22"],
    [None, None, None, "Kiểm tra customer saved successfully với numeric name", "Validation", "Projects-info-22"],
    [None, None, None, "Kiểm tra validation rules cho numeric input", "Validation", "Projects-info-22"],
]

# Insert at the beginning (or end) of Test Design
insert_position = ws_testdesign.max_row + 1
current_row = insert_position

for criteria in projects_criteria:
    ws_testdesign.cell(row=current_row, column=1).value = criteria[0]
    ws_testdesign.cell(row=current_row, column=2).value = criteria[1]
    ws_testdesign.cell(row=current_row, column=3).value = criteria[2]
    ws_testdesign.cell(row=current_row, column=4).value = criteria[3]
    ws_testdesign.cell(row=current_row, column=5).value = criteria[4]
    ws_testdesign.cell(row=current_row, column=6).value = criteria[5]
    current_row += 1

print(f"✅ Đã thêm {len(projects_criteria)} test criteria")

# ============================================================================
# SAVE FILE
# ============================================================================
output_file = 'DangBaQui_Group1_OrangeHRM_Projects_Complete.xlsx'
wb.save(output_file)

print("\n" + "=" * 80)
print("HOÀN TẤT!")
print("=" * 80)
print(f"File đã được lưu tại: {output_file}")
print(f"\n📊 Đã thêm vào Test Design:")
print(f"   • Projects: 47 criteria (TC01-TC07)")
print(f"   • Activities: 41 criteria (TC08-TC12)")
print(f"   • Customers: 61 criteria (TC13-TC22)")
print(f"   • TỔNG: {len(projects_criteria)} criteria")
# Out:
# ...
# THÊM 149 TEST CRITERIA VÀO SHEET TESTDESIGN
# ...
#
# Bước 1: Xóa Projects criteria cũ...
# ✅ Đã xóa 0 dòng cũ
#
# Bước 2: Thêm 149 test criteria mới...
# ✅ Đã thêm 149 test criteria
#
# ...
# HOÀN TẤT!
# ...
# File đã được lưu tại: DangBaQui_Group1_OrangeHRM_Projects_Complete.xlsx
#
# 📊 Đã thêm vào Test Design:
#    • Projects: 47 criteria (TC01-TC07)
#    • Activities: 41 criteria (TC08-TC12)
#    • Customers: 61 criteria (TC13-TC22)
#    • TỔNG: 149 criteria
